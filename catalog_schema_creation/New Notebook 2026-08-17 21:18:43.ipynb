# %%
# %sql
CREATE CATALOG IF NOT EXISTS mlops_dev

# %%
# %sql
create schema mlops_dev.marvel_characters

# %%
# %sql
create catalog  mlops_acc

# %%
# %sql
create schema mlops_acc.marvel_characters

# %%
# %sql
CREATE CATALOG IF NOT EXISTS mlops_prd

# %%
# %sql
create schema mlops_prd.marvel_characters
